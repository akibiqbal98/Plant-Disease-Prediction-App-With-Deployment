# %% [markdown]
# **First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.**

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook.**

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# '04_18201142 (1).pdf'
#  04_18201142_Lab03.pdf
# '04_18201142_mid (1).rar'
#  04_18201142_mid.rar
# '04_18201142 .pdf'
#  04_18201142.pdf
# '05_18201142_AkibIqbal (1).py'
#  05_18201142_AkibIqbal.py
#  102411430_267235247847921_4027082613588799638_n.jpg
#  102688967_272057017484300_1324039363227582099_n.jpg
#  102762010_692205051353599_8019120346199256491_n.jpg
# '18201142_Akib Iqbal_Assignment01_1.docx'
# '18201142_Akib Iqbal_Assignment01_1.PNG'
#  18201142_Akib_Iqbal.pdf
#  18201142_CSE321.pdf
# '18201142_MD. Akib Iqbal Majumder_02.gdoc'
#  18201142_sec05.pdf
# '18204023_Nowsheen Anjum Joya_1.mp4'
# '1. Foundations: Data, Data, Everywhere.gdoc'
# '2013 Summer CSE110 Final Exam Question Types v5.odt.gdoc'
# '2019 Summer CSE111 Midterm A v4 OBE.docx'
# '2019 Summer CSE111 Midterm A v4 OBE.gdoc'
#  20200207_122045.jpg
#  20200611_161218.jpg
#  20200611_161241.jpg
#  2021-08-14TheEconomist_UserUpload.Net.pdf
# ' 2021-Kaggle-Data-Science-Profession-Survey'
#  203971841_252130343341306_4160264162869010830_n.jpg
# '260labs Ans.rar'
# '8_18201142_MD.Akib Iqbal_Quiz 1.gdoc'
# '8.1 Machine Learning A-Z (Codes and Datasets).zip'
#  Abstract.gdoc
# 'AI startup ideas.gdoc'
# 'Akib_18201142_07_CSE423Lab2_1 (1).docx'
# 'Akib_18201142_07_CSE423Lab2_1 (2).docx'
#  Akib_18201142_07_CSE423Lab2_1.docx
# 'akib ans chegg.docx'
# 'akib ans.docx'
# 'AKIB Iqbal_18201142_07_CSE423Lab3_Code.docx'
# 'Akib Iqbal_18201142_07_CSE423Lab3_Output.png'
# 'ALL ABOUT CSE'
#  apps
# 'Audio books'
#  Brochure.gdoc
#  c5rk6rs1p.jpg
#  CamScanner_01-12-2022_16.46.pdf
# 'Capture (1).PNG'
#  Capture.PNG
# 'ch12_lecture L11.ppt_Modified.ppt'
# 'ch32_lecture L17 Mod (1).ppt'
# 'ch32_lecture L17 Mod.ppt'
#  CircularArray.java
# 'Class Needs Assessment SUM19.docx'
#  Classroom
# 'Colab Notebooks'
# 'Common Android Views Cheat Sheet.pdf'
# 'Computer vision'
# 'Copy of data_preprocessing_template.ipynb'
#  Copy_of_Differentiation_and_Richardson_Extrapolation.ipynb
#  Copy_of_Fixed_Point_Iteration.ipynb
#  Copy_of_Floating_Point_Representation.ipynb
# 'Copy of German Cover Letter [TEMPLATE].gdoc'
#  Copy_of_Lagrange_Interpolation.ipynb
# 'Copy_of_Polynomial_Root_Finding_Using_Bisection_Method (1).ipynb'
# 'Courtland L. Bovee, John V. Thill - Business Communication Essentials, 5th Edition-Prentice Hall (2011).pdf'
#  CSE220
# 'CSE220_18201142_sec(10).rar'
#  CSE221
#  cse221lab
#  CSE230
#  cse250
# 'CSE260 LAB REPORT FORMAT.docx'
#  CSE321
#  CSE428
#  CSE428.gdoc
# 'CSE Summer 2018 and Onword.pdf'
# 'D_04_18201142 (1).pdf'
# 'D_04_18201142 .pdf'
#  D_04_18201142.pdf
# 'DATASET pdf.gdoc'
# 'DF FASHIONS LETTERHEAD.gdoc'
# 'Diet for 3 months.gdoc'
# 'DoublyList (2).java'
#  entry_level_resume.gdoc
# 'Experiment No 01-Submission Form-converted.pdf'
# 'Experiment No 02-Submission Form.docx'
# 'Farid CSE.gsheet'
#  farid.gdoc
# 'Federated Generative Adversarial Learning - 1.gdoc'
# 'FINTECH Start-up.gdoc'
# 'GAN papers summary.gdoc'
#  german01.gdoc
#  Germany
# 'GRE Mock Test.gsheet'
#  Hermite_and_Newtons_Divided_Difference_Interpolation.ipynb
# 'How to get started with Drive.pdf'
#  IMPORTANT
# 'Introduction .gdoc'
#  Lab01_18201142.rar
# 'Lab05_18201142 (1).rar'
#  Lab05_18201142.rar
#  Lab2_18201142.rar
# 'Learning how to learn'
# 'LinkedList (2) (1).java'
# ' Literature Review.gdoc'
# 'Machine learning'
#  Maisha_18209011.pptx
#  mat215
#  MATLAB_120
# "MD. Akib Iqbal Majumder's Portfolio.gsite"
# 'Meghdad Akash_18209014.mp4'
# 'MGT 201 Sec 1 Group NUmber 1 -Humdard..gdoc'
# 'Monthly budget (1).gsheet'
# 'Monthly budget (2).gsheet'
# 'Monthly budget.gsheet'
#  music
# 'Mutation and repair (1).pptx'
# 'Mutation and repair.pptx'
# 'New Doc 2020-03-28 13:07:20.pdf'
# 'New Document(1).pdf'
# 'New Document(2).pdf'
# 'New Document(3).pdf'
# 'New Document(4).pdf'
# 'New Document(5).pdf'
# 'New Document.pdf'
# 'New Microsoft Word Document.gdoc'
# 'nid-5114903361 (1).pdf'
#  nid-5114903361.pdf
# 'OCT introduction.gdoc'
#  online-flight-reservation-main.zip
# 'Optical Coherence Tomography Imaging Analysis for Retinal Disease.gdoc'
# 'Ordering and Interpreting Retinal OCT Images.gdoc'
#  Pdf
# 'Pdfs submission'
# 'PODCAST 101.gdoc'
#  POL101-India-China-rivarly.gdoc
# 'Policy brief.gdoc'
#  Portfolio.gsite
# 'Practice ML (A-Z)'
#  PRB3.nb
# 'presentation (1) (1).gdoc'
# 'presentation (1).gdoc'
# 'presentation (2).gdoc'
#  presentation.gdoc
# 'Pre thesis 1 my work.gdoc'
# 'Project proposal final.gdoc'
#  Projects
# 'pull workouts.gdoc'
#  Report.gdoc
#  resume.docx
#  resume.gdoc
#  Resume.gdoc
#  Resume.pdf
#  Screenshot_20210514-011651.jpg
# 'Section 05_18204014_City Bank_Management Trainee.gslides'
# 'Semantic segmentation of aerial (satellite) imagery using U-net.gslides'
# 'Soccer Mania-Components-Recommended.gdoc'
#  Summary.gdoc
# 'thesis abstract.gdoc'
#  Untitled0.ipynb
# 'Untitled Diagram.drawio'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled Jam (1).gjam'
# 'Untitled Jam (2).gjam'
# 'Untitled Jam (3).gjam'
# 'Untitled Jam (4).gjam'
# 'Untitled Jam (5).gjam'
# 'Untitled Jam (6).gjam'
# 'Untitled Jam.gjam'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet.gsheet'
#  wallpaper
# 'Why are you doing this.gdoc'
#  workout
# 'workout routine.gdoc'
#  workouts.gdoc
#  Yoo
# 'Your big idea.gslides'

# %% [markdown]
# **Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers  import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import model_from_json
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# **Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.**

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Projects/Plant_Disease/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img) # this is a matplotlib method 
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# **After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.**

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# **Now we will convert all the images into numpy array.**

# %%
dir = "/content/drive/My Drive/Projects/Plant_Disease"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# **We will also observe the number of images under different classes to see if the dataset is balanced or not**

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %% [markdown]
# **Next we will observe the shape of the image.**

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# **Checking the total number of the images which is the length of the labels list.**

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
# One hut encoding
y_train = to_categorical(y_train) 
y_test = to_categorical(y_test)

# %% [markdown]
# **Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).**

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3))) # MaxPooling2D is a down sampling technique, which is used to take out the maximum value of the window defined by the size.
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten()) # Flatten layer ,which is require before the dense layer
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax")) # softmax, which is the activation function for classification problems
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 256, 256, 32)      896
#
#  max_pooling2d_6 (MaxPooling  (None, 85, 85, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 85, 85, 16)        4624
#
#  max_pooling2d_7 (MaxPooling  (None, 42, 42, 16)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 28224)             0
#
#  dense_6 (Dense)             (None, 8)                 225800
#
#  dense_7 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Training the model
epochs = 100
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9792
# Epoch 2/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9792
# Epoch 3/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9792
# Epoch 4/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9792
# Epoch 5/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9792
# Epoch 6/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9792
# Epoch 7/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9792
# Epoch 8/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9792
# Epoch 9/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9792
# Epoch 10/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9792
# Epoch 11/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9792
# Epoch 12/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9792
# Epoch 13/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9792
# Epoch 14/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9792
# Epoch 15/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9792
# Epoch 16/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9792
# Epoch 17/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9792
# Epoch 18/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9792
# Epoch 19/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9792
# Epoch 20/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9792
# Epoch 21/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9792
# Epoch 22/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9792
# Epoch 23/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9792
# Epoch 24/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9792
# Epoch 25/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9792
# Epoch 26/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9792
# Epoch 27/100
# 5/5 [==============================] - 1s 159ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9792
# Epoch 28/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9792
# Epoch 29/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9792
# Epoch 30/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9792
# Epoch 31/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9792
# Epoch 32/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9792
# Epoch 33/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9792
# Epoch 34/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9792
# Epoch 35/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9792
# Epoch 36/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9792
# Epoch 37/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9792
# Epoch 38/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9792
# Epoch 39/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9792
# Epoch 40/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9792
# Epoch 41/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9792
# Epoch 42/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9792
# Epoch 43/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 0.9792
# Epoch 44/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9792
# Epoch 45/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1290 - val_accuracy: 0.9792
# Epoch 46/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9792
# Epoch 47/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9792
# Epoch 48/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9792
# Epoch 49/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9792
# Epoch 50/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9792
# Epoch 51/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9792
# Epoch 52/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9792
# Epoch 53/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9792
# Epoch 54/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9792
# Epoch 55/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9792
# Epoch 56/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9792
# Epoch 57/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9792
# Epoch 58/100
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9792
# Epoch 59/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9792
# Epoch 60/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9792
# Epoch 61/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9792
# Epoch 62/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9792
# Epoch 63/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9792
# Epoch 64/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9792
# Epoch 65/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9792
# Epoch 66/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9792
# Epoch 67/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9792
# Epoch 68/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9792
# Epoch 69/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9792
# Epoch 70/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9792
# Epoch 71/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9792
# Epoch 72/100
# 5/5 [==============================] - 1s 170ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9792
# Epoch 73/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9792
# Epoch 74/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9792
# Epoch 75/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 0.9792
# Epoch 76/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9792
# Epoch 77/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9792
# Epoch 78/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9792
# Epoch 79/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9792
# Epoch 80/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9792
# Epoch 81/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9792
# Epoch 82/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9792
# Epoch 83/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9792
# Epoch 84/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9792
# Epoch 85/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9792
# Epoch 86/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9792
# Epoch 87/100
# 5/5 [==============================] - 1s 173ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9792
# Epoch 88/100
# 5/5 [==============================] - 1s 174ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9792
# Epoch 89/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9792
# Epoch 90/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9792
# Epoch 91/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9792
# Epoch 92/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9792
# Epoch 93/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 0.9792
# Epoch 94/100
# 5/5 [==============================] - 1s 165ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9792
# Epoch 95/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9792
# Epoch 96/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9792
# Epoch 97/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9792
# Epoch 98/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9792
# Epoch 99/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9792
# Epoch 100/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9792

# %% [markdown]
# Saving the model using different techniques.

# %%
model.save("/content/drive/My Drive/Projects/Models/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('/content/drive/My Drive/Projects/Models/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('/content/drive/My Drive/Projects/Models/plant_model_weights.h5')

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0331 - accuracy: 0.9944
# Test Accuracy: 99.44444298744202

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
y_pred = model.predict(x_test)

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F70604EF090>

# %% [markdown]
# Printing out the original and the predicted label.

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.
